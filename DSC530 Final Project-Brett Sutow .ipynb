# %%
#Setup#
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import thinkplot
import scatter

# %%
#Loads data for baseball players that will be looked at#
BarryBonds= pd.read_csv('/Users/Brett/Desktop/BarryBonds.csv')
BabeRuth= pd.read_csv('/Users/Brett/Desktop/BabeRuth.csv')
HankAaron= pd.read_csv('/Users/Brett/Desktop/HankAaron.csv')
ARod= pd.read_csv('/Users/Brett/Desktop/AlexRodriguez.csv')
WillieMays= pd.read_csv('/Users/Brett/Desktop/WillieMays.csv')
print(BarryBonds,BabeRuth,HankAaron,ARod,WillieMays)
# Out:
#     Year  Age   Tm  Lg    G    R    H  2B  HR  RBI     BA    OBP    SLG
# 0   1986   21  PIT  NL  113   72   92  26  16   48  0.223  0.330  0.416
# 1   1987   22  PIT  NL  150   99  144  34  25   59  0.261  0.329  0.492
# 2   1988   23  PIT  NL  144   97  152  30  24   58  0.283  0.368  0.491
# 3   1989   24  PIT  NL  159   96  144  34  19   58  0.248  0.351  0.426
# 4   1990   25  PIT  NL  151  104  156  32  33  114  0.301  0.406  0.565
# 5   1991   26  PIT  NL  153   95  149  28  25  116  0.292  0.410  0.514
# 6   1992   27  PIT  NL  140  109  147  36  34  103  0.311  0.456  0.624
# 7   1993   28  SFG  NL  159  129  181  38  46  123  0.336  0.458  0.677
# 8   1994   29  SFG  NL  112   89  122  18  37   81  0.312  0.426  0.647
# 9   1995   30  SFG  NL  144  109  149  30  33  104  0.294  0.431  0.577
# 10  1996   31  SFG  NL  158  122  159  27  42  129  0.308  0.461  0.615
# 11  1997   32  SFG  NL  159  123  155  26  40  101  0.291  0.446  0.585
# ...

# %%
#Describes Data for each player#
print('Barry Bonds Descriptive Statistics')
BarryBonds.describe()
# Out:
# Barry Bonds Descriptive Statistics
#               Year        Age           G           R           H         2B  \
# count    21.000000  21.000000   21.000000   21.000000   21.000000  21.000000
# mean   1996.000000  31.000000  136.190476  102.476190  135.285714  27.952381
# std       6.204837   6.204837   32.441669   27.760798   36.424089   8.674539
# min    1986.000000  21.000000   14.000000    8.000000   12.000000   1.000000
# 25%    1991.000000  26.000000  130.000000   95.000000  133.000000  26.000000
# 50%    1996.000000  31.000000  144.000000  109.000000  147.000000  28.000000
# 75%    2001.000000  36.000000  153.000000  122.000000  155.000000  32.000000
# max    2006.000000  41.000000  159.000000  129.000000  181.000000  44.000000
#
#               HR         RBI         BA        OBP        SLG
# count  21.000000   21.000000  20.000000  20.000000  20.000000
# mean   34.952381   91.904762   0.300900   0.438900   0.621650
# ...

# %%
print('Babe Ruth Descriptive Statistics')

BabeRuth.describe()
# Out:
# Babe Ruth Descriptive Statistics
#               Year        Age           G           R           H         2B  \
# count    22.000000  22.000000   22.000000   22.000000   22.000000  22.000000
# mean   1924.500000  29.500000  113.772727   98.818182  130.590909  23.000000
# std       6.493587   6.493587   45.971971   58.314938   67.753516  13.373748
# min    1914.000000  19.000000    5.000000    1.000000    2.000000   0.000000
# 25%    1919.250000  24.250000   95.750000   52.750000   97.250000  12.250000
# 50%    1924.500000  29.500000  134.000000  111.500000  147.500000  26.000000
# 75%    1929.750000  34.750000  149.500000  149.750000  185.500000  30.750000
# max    1935.000000  40.000000  154.000000  177.000000  205.000000  45.000000
#
#               HR         RBI         BA        OBP        SLG
# count  22.000000   22.000000  21.000000  21.000000  21.000000
# mean   32.454545  100.636364   0.329619   0.444810   0.643667
# ...

# %%
print('Hank Aaron Descriptive Statistics')

HankAaron.describe()
# Out:
# Hank Aaron Descriptive Statistics
#              Year       Age           G           R           H         2B  \
# count    23.00000  23.00000   23.000000   23.000000   23.000000  23.000000
# mean   1965.00000  31.00000  143.391304   94.521739  163.956522  27.130435
# std       6.78233   6.78233   18.509799   27.660062   40.597221  10.087365
# min    1954.00000  20.00000   85.000000   22.000000   62.000000   8.000000
# 25%    1959.50000  25.50000  138.000000   84.000000  142.500000  21.000000
# 50%    1965.00000  31.00000  151.000000  103.000000  174.000000  28.000000
# 75%    1970.50000  36.50000  154.500000  114.000000  193.500000  34.000000
# max    1976.00000  42.00000  161.000000  127.000000  223.000000  46.000000
#
#               HR         RBI         BA        OBP        SLG
# count  23.000000   23.000000  23.000000  23.000000  23.000000
# mean   32.826087   99.869565   0.301174   0.371913   0.547696
# std    11.182991   25.706922   0.031162   0.026221   0.078515
# ...

# %%
print('Alex Rodriguez Descriptive Statistics')

ARod.describe()
# Out:
# Alex Rodriguez Descriptive Statistics
#              Year        Age           G           R           H         2B  \
# count    23.00000  22.000000   22.000000   22.000000   22.000000  22.000000
# mean   2005.00000  28.590909  126.545455   91.863636  141.590909  24.909091
# std       6.78233   6.645149   43.723947   43.375762   60.566893  12.493461
# min    1994.00000  18.000000   17.000000    4.000000   11.000000   0.000000
# 25%    1999.50000  23.250000  122.500000   74.000000  126.250000  18.000000
# 50%    2005.00000  28.500000  143.500000  107.000000  160.000000  26.500000
# 75%    2010.50000  33.750000  157.250000  124.000000  182.500000  32.500000
# max    2016.00000  40.000000  162.000000  143.000000  215.000000  54.000000
#
#               HR         RBI         BA        OBP        SLG
# count  22.000000   22.000000  22.000000  22.000000  22.000000
# mean   31.636364   94.818182   0.283273   0.363818   0.517636
# ...

# %%
print('Willie Mays Descriptive Statistics')

WillieMays.describe()
# Out:
# Willie Mays Descriptive Statistics
#               Year        Age           G           R           H         2B  \
# count    25.000000  24.000000   24.000000   24.000000   24.000000  24.000000
# mean   1962.800000  32.208333  128.333333   87.375000  139.333333  22.250000
# std       7.059273   6.902924   41.431627   39.354368   59.176719  10.530494
# min    1951.000000  20.000000   19.000000    8.000000    9.000000   2.000000
# 25%    1957.000000  26.750000  120.000000   62.750000  113.750000  16.500000
# 50%    1963.000000  32.500000  151.000000  100.000000  165.000000  22.000000
# 75%    1969.000000  38.250000  152.250000  119.500000  185.500000  29.750000
# max    1973.000000  42.000000  162.000000  130.000000  208.000000  43.000000
#
#               HR         RBI         BA        OBP        SLG
# count  24.000000   24.000000  24.000000  24.000000  24.000000
# mean   27.833333   80.208333   0.288250   0.380750   0.520083
# ...

# %%
#Drops N/A for Willie Mays and Alex Rodriguez# 
WillieMays= WillieMays.dropna()
ARod=ARod.dropna()

# %%
#Create Histogram for the players for hits, doubles, rbis, homeruns, batting average#
#Barry Bonds HR# 
plt.hist(BarryBonds['HR'], bins = 30, color='orange')
plt.xlabel('Homeruns', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Barry Bonds Homeruns Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Barry Bonds Homeruns Plot')

# %%
#Barry Bonds RBI# 
plt.hist(BarryBonds['RBI'], bins = 30, color='orange')
plt.xlabel('RBI', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Barry Bonds RBI Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Barry Bonds RBI Plot')

# %%
#Barry Bonds Hits# 
plt.hist(BarryBonds['H'], bins = 30, color='orange')
plt.xlabel('Hits', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Barry Bonds Hits Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Barry Bonds Hits Plot')

# %%
#Barry Bonds Doubles# 
plt.hist(BarryBonds['2B'], bins = 30, color='orange')
plt.xlabel('Doubles', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Barry Bonds Doubles Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Barry Bonds Doubles Plot')

# %%
#Barry Bonds Batting Average# 
plt.hist(BarryBonds['BA'], bins = 30, color='orange')
plt.xlabel('Batting Average', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Barry Bonds Batting Average Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Barry Bonds Batting Average Plot')

# %%
#Babe Ruth HR# 
plt.hist(BabeRuth['HR'], bins = 30, color='blue')
plt.xlabel('Homeruns', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Babe Ruth Homeruns Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Babe Ruth Homeruns Plot')

# %%
#Babe Ruth RBI# 
plt.hist(BabeRuth['RBI'], bins = 30, color='blue')
plt.xlabel('RBI', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Babe Ruth RBI Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Babe Ruth RBI Plot')

# %%
#Babe Ruth Hits# 
plt.hist(BabeRuth['H'], bins = 30, color='blue')
plt.xlabel('Hits', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Babe Ruth Hits Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Babe Ruth Hits Plot')

# %%
#Babe Ruth Doubles# 
plt.hist(BabeRuth['2B'], bins = 30, color='blue')
plt.xlabel('Doubles', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Babe Ruth Doubles Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Babe Ruth Doubles Plot')

# %%
#Babe Ruth Batting Average# 
plt.hist(BabeRuth['BA'], bins = 30, color='blue')
plt.xlabel('Batting Average', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Babe Ruth Batting Average Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Babe Ruth Batting Average Plot')

# %%
#Hank Aaron HR# 
plt.hist(HankAaron['HR'], bins = 30, color='red')
plt.xlabel('Homeruns', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Hank Aaron Homeruns Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Hank Aaron Homeruns Plot')

# %%
#Hank Aaron RBI# 
plt.hist(HankAaron['RBI'], bins = 30, color='red')
plt.xlabel('RBI', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Hank Aaron RBI Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Hank Aaron RBI Plot')

# %%
#Hank Aaron Hits# 
plt.hist(HankAaron['H'], bins = 30, color='red')
plt.xlabel('Hits', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Hank Aaron Hits Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Hank Aaron Hits Plot')

# %%
#Hank Aaron Doubles# 
plt.hist(HankAaron['2B'], bins = 30, color='red')
plt.xlabel('Doubles', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Hank Aaron Doubles Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Hank Aaron Doubles Plot')

# %%
#Hank Aaron Batting Average# 
plt.hist(HankAaron['BA'], bins = 30, color='red')
plt.xlabel('Batting Average', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Hank Aaron Batting Average Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Hank Aaron Batting Average Plot')

# %%
#Willie Mays HR# 
plt.hist(WillieMays['HR'], bins = 30, color='black')
plt.xlabel('Homeruns', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Willie Mays Homeruns Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Willie Mays Homeruns Plot')

# %%
#Willie Mays RBI# 
plt.hist(WillieMays['RBI'], bins = 30, color='black')
plt.xlabel('RBI', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Willie Mays RBI Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Willie Mays RBI Plot')

# %%
#Willie Mays Hits# 
plt.hist(WillieMays['H'], bins = 30, color='black')
plt.xlabel('Hits', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Willie Mays Hits Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Willie Mays Hits Plot')

# %%
#Willie Mays Doubles# 
plt.hist(WillieMays['2B'], bins = 30, color='black')
plt.xlabel('Doubles', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Willie Mays Doubles Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Willie Mays Doubles Plot')

# %%
#Willie Mays Batting Average# 
plt.hist(WillieMays['BA'], bins = 30, color='black')
plt.xlabel('Batting Average', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Willie Mays Batting Average Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Willie Mays Batting Average Plot')

# %%
#ARod HR# 
plt.hist(ARod['HR'], bins = 30, color='green')
plt.xlabel('Homeruns', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Alex Rodriguez Homeruns Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Alex Rodriguez Homeruns Plot')

# %%
# ARod RBI# 
plt.hist(ARod['RBI'], bins = 30, color='green')
plt.xlabel('RBI', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Alex Rodriguez RBI Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Alex Rodriguez RBI Plot')

# %%
#ARod Hits# 
plt.hist(ARod['H'], bins = 30, color='green')
plt.xlabel('Hits', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Alex Rodriguez Hits Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Alex Rodriguez Hits Plot')

# %%
#ARod Doubles# 
plt.hist(ARod['2B'], bins = 30, color='green')
plt.xlabel('Doubles', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Alex Rodriguez Doubles Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Alex Rodriguez Doubles Plot')

# %%
#ARod Batting Average# 
plt.hist(ARod['BA'], bins = 30, color='green')
plt.xlabel('Batting Average', fontsize=10)
plt.ylabel('Counts', fontsize=10)
plt.title('Alex Rodriguez Batting Average Plot',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Alex Rodriguez Batting Average Plot')

# %%
#PMF for comparing homeruns between players pmf following#
import thinkstats2 
print('Barry Bonds:', thinkstats2.Pmf(BarryBonds['HR']))
print('Babe Ruth:',thinkstats2.Pmf(BabeRuth['HR']))
print('Hank Aaron:',thinkstats2.Pmf(HankAaron['HR']))
print('Willie Mays:',thinkstats2.Pmf(WillieMays['HR']))
print('Alex Rodriguez:',thinkstats2.Pmf(ARod['HR']))
# Out:
# Barry Bonds: Pmf({25: 0.09523809523809523, 46: 0.09523809523809523, 45: 0.09523809523809523, 37: 0.09523809523809523, 34: 0.09523809523809523, 33: 0.09523809523809523, 26: 0.047619047619047616, 24: 0.047619047619047616, 5: 0.047619047619047616, 19: 0.047619047619047616, 49: 0.047619047619047616, 16: 0.047619047619047616, 42: 0.047619047619047616, 73: 0.047619047619047616, 40: 0.047619047619047616})
# Babe Ruth: Pmf({46: 0.13636363636363635, 54: 0.09090909090909091, 41: 0.09090909090909091, 29: 0.045454545454545456, 2: 0.045454545454545456, 3: 0.045454545454545456, 4: 0.045454545454545456, 6: 0.045454545454545456, 11: 0.045454545454545456, 47: 0.045454545454545456, 60: 0.045454545454545456, 49: 0.045454545454545456, 22: 0.045454545454545456, 34: 0.045454545454545456, 25: 0.045454545454545456, 35: 0.045454545454545456, 59: 0.045454545454545456, 0: 0.045454545454545456})
# ...

# %%
#PMF for comparing hits between players pmf following#
print('Barry Bonds:', thinkstats2.Pmf(BarryBonds['H']))
print('Babe Ruth:',thinkstats2.Pmf(BabeRuth['H']))
print('Hank Aaron:',thinkstats2.Pmf(HankAaron['H']))
print('Willie Mays:',thinkstats2.Pmf(WillieMays['H']))
print('Alex Rodriguez:',thinkstats2.Pmf(ARod['H']))
# Out:
# Barry Bonds: Pmf({149: 0.14285714285714285, 147: 0.09523809523809523, 144: 0.09523809523809523, 156: 0.09523809523809523, 159: 0.047619047619047616, 93: 0.047619047619047616, 92: 0.047619047619047616, 155: 0.047619047619047616, 122: 0.047619047619047616, 135: 0.047619047619047616, 152: 0.047619047619047616, 181: 0.047619047619047616, 12: 0.047619047619047616, 167: 0.047619047619047616, 133: 0.047619047619047616, 99: 0.047619047619047616})
# ...

# %%
#PMF for comparing RBIs between players pmf following#
print('Barry Bonds:', thinkstats2.Pmf(BarryBonds['RBI']))
print('Babe Ruth:',thinkstats2.Pmf(BabeRuth['RBI']))
print('Hank Aaron:',thinkstats2.Pmf(HankAaron['RBI']))
print('Willie Mays:',thinkstats2.Pmf(WillieMays['RBI']))
print('Alex Rodriguez:',thinkstats2.Pmf(ARod['RBI']))
# Out:
# Barry Bonds: Pmf({101: 0.09523809523809523, 58: 0.09523809523809523, 59: 0.047619047619047616, 77: 0.047619047619047616, 137: 0.047619047619047616, 103: 0.047619047619047616, 104: 0.047619047619047616, 123: 0.047619047619047616, 106: 0.047619047619047616, 10: 0.047619047619047616, 110: 0.047619047619047616, 48: 0.047619047619047616, 81: 0.047619047619047616, 114: 0.047619047619047616, 83: 0.047619047619047616, 116: 0.047619047619047616, 90: 0.047619047619047616, 122: 0.047619047619047616, 129: 0.047619047619047616})
# ...

# %%
#CDF for Homeruns#
print('Barry Bonds CDF')
print(thinkstats2.Cdf(BarryBonds.HR))

print('')

print('Babe Ruth CDF')
print(thinkstats2.Cdf(BabeRuth.HR))
print('')

print('Hank Aaron CDF')
print(thinkstats2.Cdf(HankAaron.HR))
print('')

print('Willie Mays CDF')
print(thinkstats2.Cdf(WillieMays.HR))
print('')

print('Alex Rodriguez CDF')
print(thinkstats2.Cdf(ARod.HR))
# Out:
# Barry Bonds CDF
# Cdf([ 5 16 19 24 25 26 33 34 37 40 42 45 46 49 73], [0.04761905 0.0952381  0.14285714 0.19047619 0.28571429 0.33333333
#  0.42857143 0.52380952 0.61904762 0.66666667 0.71428571 0.80952381
#  0.9047619  0.95238095 1.        ])
#
# Babe Ruth CDF
# Cdf([ 0  2  3  4  6 11 22 25 29 34 35 41 46 47 49 54 59 60], [0.04545455 0.09090909 0.13636364 0.18181818 0.22727273 0.27272727
#  0.31818182 0.36363636 0.40909091 0.45454545 0.5        0.59090909
#  0.72727273 0.77272727 0.81818182 0.90909091 0.95454545 1.        ])
#
# Hank Aaron CDF
# Cdf([10 12 13 20 24 26 27 29 30 32 34 38 39 40 44 45 47], [0.04347826 0.08695652 0.13043478 0.17391304 0.2173913  0.26086957
#  0.30434783 0.34782609 0.39130435 0.43478261 0.52173913 0.56521739
#  0.65217391 0.73913043 0.91304348 0.95652174 1.        ])
#
# Willie Mays CDF
# Cdf([ 0.  4.  6.  8. 13. 18. 20. 22. 23. 28. 29. 34. 35. 36. 37. 38. 40. 41.
#  47. 49. 51. 52.], [0.04166667 0.08333333 0.125      0.20833333 0.25       0.29166667
# ...

# %%
#CDF for Hits#
print('Barry Bonds CDF')
print(thinkstats2.Cdf(BarryBonds.H))

print('')

print('Babe Ruth CDF')
print(thinkstats2.Cdf(BabeRuth.H))
print('')

print('Hank Aaron CDF')
print(thinkstats2.Cdf(HankAaron.H))
print('')

print('Willie Mays CDF')
print(thinkstats2.Cdf(WillieMays.H))
print('')

print('Alex Rodriguez CDF')
print(thinkstats2.Cdf(ARod.H))
# Out:
# Barry Bonds CDF
# Cdf([ 12  92  93  99 122 133 135 144 147 149 152 155 156 159 167 181], [0.04761905 0.0952381  0.14285714 0.19047619 0.23809524 0.28571429
#  0.33333333 0.42857143 0.52380952 0.66666667 0.71428571 0.76190476
#  0.85714286 0.9047619  0.95238095 1.        ])
#
# Babe Ruth CDF
# Cdf([  2  13  29  37  40  95 104 105 128 138 139 156 172 173 184 186 192 199
#  200 204 205], [0.04545455 0.09090909 0.13636364 0.18181818 0.22727273 0.27272727
#  0.31818182 0.36363636 0.40909091 0.45454545 0.5        0.54545455
#  0.63636364 0.68181818 0.72727273 0.77272727 0.81818182 0.86363636
#  0.90909091 0.95454545 1.        ])
#
# Hank Aaron CDF
# Cdf([ 62  91 109 118 119 131 154 162 164 168 172 174 181 184 187 189 191 196
#  197 198 200 201 223], [0.04347826 0.08695652 0.13043478 0.17391304 0.2173913  0.26086957
#  0.30434783 0.34782609 0.39130435 0.43478261 0.47826087 0.52173913
#  0.56521739 0.60869565 0.65217391 0.69565217 0.73913043 0.7826087
# ...

# %%
#CDF for RBIs
print('Barry Bonds CDF')
print(thinkstats2.Cdf(BarryBonds.RBI))

print('')

print('Babe Ruth CDF')
print(thinkstats2.Cdf(BabeRuth.RBI))
print('')

print('Hank Aaron CDF')
print(thinkstats2.Cdf(HankAaron.RBI))
print('')

print('Willie Mays CDF')
print(thinkstats2.Cdf(WillieMays.RBI))
print('')

print('Alex Rodriguez CDF')
print(thinkstats2.Cdf(ARod.RBI))
# Out:
# Barry Bonds CDF
# Cdf([ 10  48  58  59  77  81  83  90 101 103 104 106 110 114 116 122 123 129
#  137], [0.04761905 0.0952381  0.19047619 0.23809524 0.28571429 0.33333333
#  0.38095238 0.42857143 0.52380952 0.57142857 0.61904762 0.66666667
#  0.71428571 0.76190476 0.80952381 0.85714286 0.9047619  0.95238095
#  1.        ])
#
# Babe Ruth CDF
# Cdf([  0  12  14  16  20  61  67  84  96 104 113 124 130 135 137 146 153 154
#  162 165 168], [0.04545455 0.09090909 0.13636364 0.18181818 0.22727273 0.27272727
#  0.31818182 0.36363636 0.40909091 0.45454545 0.5        0.54545455
#  0.59090909 0.63636364 0.68181818 0.72727273 0.81818182 0.86363636
#  0.90909091 0.95454545 1.        ])
#
# Hank Aaron CDF
# Cdf([ 35  60  69  77  86  89  92  95  96  97 106 109 118 120 123 126 127 128
#  130 132], [0.04347826 0.08695652 0.17391304 0.2173913  0.26086957 0.30434783
#  0.34782609 0.43478261 0.47826087 0.52173913 0.56521739 0.60869565
#  0.69565217 0.73913043 0.7826087  0.82608696 0.86956522 0.91304348
# ...

# %%
#Plots HR CDF#

BBHR=thinkstats2.Cdf(BarryBonds.HR)
thinkplot.Cdf(BBHR)
thinkplot.Show( xlabel='HR', ylabel='CDF', title='Barry Bonds CDF HR')

# %%
print('Babe Ruth CDF')
BRHR=thinkstats2.Cdf(BabeRuth.RBI)
thinkplot.Cdf(BRHR)
thinkplot.Show( xlabel='HR', ylabel='CDF', title='Babe Ruth CDF HR')
# Out:
# Babe Ruth CDF

# %%
print('Hank Aaron CDF')
HAHR=thinkstats2.Cdf(HankAaron.RBI)
thinkplot.Cdf(HAHR)
thinkplot.Show( xlabel='HR', ylabel='CDF', title='Hank Aaron CDF HR')
# Out:
# Hank Aaron CDF

# %%
print('Willie Mays CDF')
WMHR=thinkstats2.Cdf(WillieMays.RBI)
thinkplot.Cdf(WMHR)
thinkplot.Show( xlabel='HR', ylabel='CDF', title='Willie Mays CDF HR')
# Out:
# Willie Mays CDF

# %%
print('Alex Rodriguez CDF')
ARHR=thinkstats2.Cdf(ARod.RBI)
thinkplot.Cdf(ARHR)
thinkplot.Show( xlabel='HR', ylabel='CDF', title='Alex Rodriguez CDF HR')
# Out:
# Alex Rodriguez CDF

# %%
#Plots Hits CDF#
print('Barry Bonds CDF')
BBH=thinkstats2.Cdf(BarryBonds.H)
thinkplot.Cdf(BBH)
thinkplot.Show( xlabel='H', ylabel='CDF', title='Barry Bonds CDF Hits')
# Out:
# Barry Bonds CDF

# %%
BRH=thinkstats2.Cdf(BabeRuth.H)
thinkplot.Cdf(BRH)
thinkplot.Show( xlabel='H', ylabel='CDF', title='Babe Ruth CDF Hits')

# %%
HAH=thinkstats2.Cdf(HankAaron.H)
thinkplot.Cdf(HAH)
thinkplot.Show( xlabel='H', ylabel='CDF', title='Hank Aaron CDF Hits')

# %%
WMH=thinkstats2.Cdf(WillieMays.H)
thinkplot.Cdf(WMH)
thinkplot.Show( xlabel='H', ylabel='CDF', title='Willie Mays CDF Hits')

# %%
ARH=thinkstats2.Cdf(ARod.H)
thinkplot.Cdf(ARH)
thinkplot.Show( xlabel='H', ylabel='CDF', title='Alex Rodriguez CDF Hits')

# %%
#Plots RBI CDF#
BBR=thinkstats2.Cdf(BarryBonds.RBI)
thinkplot.Cdf(BBR)
thinkplot.Show( xlabel='RBI', ylabel='CDF', title='Barry Bonds CDF RBI')

# %%
BRR=thinkstats2.Cdf(BabeRuth.RBI)
thinkplot.Cdf(BRR)
thinkplot.Show( xlabel='RBI', ylabel='CDF', title='Babe Ruth CDF RBI')

# %%
HAR=thinkstats2.Cdf(HankAaron.RBI)
thinkplot.Cdf(HAR)
thinkplot.Show( xlabel='RBI', ylabel='CDF', title='Hank Aaron CDF RBI')

# %%
WMR=thinkstats2.Cdf(WillieMays.RBI)
thinkplot.Cdf(WMR)
thinkplot.Show( xlabel='RBI', ylabel='CDF', title='Willie Mays CDF RBI')

# %%
ARR=thinkstats2.Cdf(ARod.RBI)
thinkplot.Cdf(ARR)
thinkplot.Show( xlabel='RBI', ylabel='CDF', title='Alex Rodriguez CDF RBI')

# %%
print('Barry Bonds Homeruns Normal Probability Plot')
import scipy.stats
mean = BarryBonds.HR.mean()
std = BarryBonds.HR.std()

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, inter=mean, slope=std)
thinkplot.Plot(fxs, fys, color='orange', label='model')

xs, ys = thinkstats2.NormalProbability(BarryBonds.HR)

thinkplot.Plot(xs, ys)
# Out:
# Barry Bonds Homeruns Normal Probability Plot

# %%
print('Babe Ruth Homeruns Normal Probability Plot')
import scipy.stats
mean = BabeRuth.HR.mean()
std = BabeRuth.HR.std()

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, inter=mean, slope=std)
thinkplot.Plot(fxs, fys, color='blue', label='model')

xs, ys = thinkstats2.NormalProbability(BabeRuth.HR)

thinkplot.Plot(xs, ys)
# Out:
# Babe Ruth Homeruns Normal Probability Plot

# %%
print('Hank Aaron Homeruns Normal Probability Plot')
import scipy.stats
mean = HankAaron.HR.mean()
std = HankAaron.HR.std()

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, inter=mean, slope=std)
thinkplot.Plot(fxs, fys, color='red', label='model')

xs, ys = thinkstats2.NormalProbability(HankAaron.HR)

thinkplot.Plot(xs, ys)
# Out:
# Hank Aaron Homeruns Normal Probability Plot

# %%
print('Willie Mays Homeruns Normal Probability Plot')
import scipy.stats
mean = WillieMays.HR.mean()
std = WillieMays.HR.std()

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, inter=mean, slope=std)
thinkplot.Plot(fxs, fys, color='black', label='model')

xs, ys = thinkstats2.NormalProbability(WillieMays.HR)

thinkplot.Plot(xs, ys)
# Out:
# Willie Mays Homeruns Normal Probability Plot

# %%
print('Alex Rodriguez Homeruns Normal Probability Plot')
import scipy.stats
mean = ARod.HR.mean()
std = ARod.HR.std()

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, inter=mean, slope=std)
thinkplot.Plot(fxs, fys, color='green', label='model')

xs, ys = thinkstats2.NormalProbability(ARod.HR)

thinkplot.Plot(xs, ys)
# Out:
# Alex Rodriguez Homeruns Normal Probability Plot

# %%
#Graphs scatter plots for Homeruns and age for all the players# 
plt.scatter(x=BarryBonds['Age'], y=BarryBonds['HR'])
plt.xlabel('Age')
plt.ylabel('Homeruns')
plt.title('Barry Bonds Age vs Homeruns')
# Out:
# Text(0.5, 1.0, 'Barry Bonds Age vs Homeruns')

# %%
plt.scatter(x=BabeRuth['Age'], y=BabeRuth['HR'])
plt.xlabel('Age')
plt.ylabel('Homeruns')
plt.title('Babe Ruth Age vs Homeruns')
# Out:
# Text(0.5, 1.0, 'Babe Ruth Age vs Homeruns')

# %%
plt.scatter(x=HankAaron['Age'], y=HankAaron['HR'])
plt.xlabel('Age')
plt.ylabel('Homeruns')
plt.title('Hank Aaron Age vs Homeruns')
# Out:
# Text(0.5, 1.0, 'Hank Aaron Age vs Homeruns')

# %%
plt.scatter(x=WillieMays['Age'], y=WillieMays['HR'])
plt.xlabel('Age')
plt.ylabel('Homeruns')
plt.title('Willie Mays Age vs Homeruns')
# Out:
# Text(0.5, 1.0, 'Willie Mays Age vs Homeruns')

# %%
plt.scatter(x=ARod['Age'], y=ARod['HR'])
plt.xlabel('Age')
plt.ylabel('Homeruns')
plt.title('Alex Rodriguez Age vs Homeruns')
# Out:
# Text(0.5, 1.0, 'Alex Rodriguez Age vs Homeruns')

# %%
#Creates scatter plot looking at hits and age#
plt.scatter(x=BarryBonds['Age'], y=BarryBonds['H'])
plt.xlabel('Age')
plt.ylabel('Hits')
plt.title('Barry Bonds Age vs Hits')
# Out:
# Text(0.5, 1.0, 'Barry Bonds Age vs Hits')

# %%
plt.scatter(x=BabeRuth['Age'], y=BabeRuth['H'])
plt.xlabel('Age')
plt.ylabel('Hits')
plt.title('Babe Ruth Age vs Hits')
# Out:
# Text(0.5, 1.0, 'Babe Ruth Age vs Hits')

# %%
plt.scatter(x=HankAaron['Age'], y=HankAaron['H'])
plt.xlabel('Age')
plt.ylabel('Hits')
plt.title('Hank Aaron Age vs Hits')
# Out:
# Text(0.5, 1.0, 'Hank Aaron Age vs Hits')

# %%
plt.scatter(x=WillieMays['Age'], y=WillieMays['H'])
plt.xlabel('Age')
plt.ylabel('Hits')
plt.title('Willie Mays Age vs Hits')
# Out:
# Text(0.5, 1.0, 'Willie Mays Age vs Hits')

# %%
plt.scatter(x=ARod['Age'], y=ARod['H'])
plt.xlabel('Age')
plt.ylabel('Hits')
plt.title('Alex Rodriguez Age vs Hits')
# Out:
# Text(0.5, 1.0, 'Alex Rodriguez Age vs Hits')

# %%
#Creates Covariance Matrix for age and homeruns#
print('Barry Bonds Covariance Homeruns')
BBHRCOV= np.array([BarryBonds.Age,BarryBonds.HR])
covMatrix1 = np.cov(BBHRCOV,bias=True)
covMatrix1
# Out:
# Barry Bonds Covariance Homeruns
# array([[ 36.66666667,  29.47619048],
#        [ 29.47619048, 194.90249433]])

# %%
print('Babe Ruth Covariance Homeruns')
BRHRCOV= np.array([BabeRuth.Age,BabeRuth.HR])
covMatrix2 = np.cov(BRHRCOV,bias=True)
covMatrix2
# Out:
# Babe Ruth Covariance Homeruns
# array([[ 40.25      ,  51.59090909],
#        [ 51.59090909, 389.88429752]])

# %%
print('Hank Aaron Covariance Homeruns')
HAHRCOV= np.array([HankAaron.Age,HankAaron.HR])
covMatrix3 = np.cov(HAHRCOV,bias=True)
covMatrix3
# Out:
# Hank Aaron Covariance Homeruns
# array([[ 44.        ,  -8.73913043],
#        [ -8.73913043, 119.62192817]])

# %%
print('Willie Mays Covariance Homeruns')
WMHRCOV= np.array([WillieMays.Age.fillna(0),WillieMays.HR.fillna(0)])
covMatrix4 = np.cov(WMHRCOV,bias=True)
covMatrix4
# Out:
# Willie Mays Covariance Homeruns
# array([[ 45.66493056, -44.67361111],
#        [-44.67361111, 235.22222222]])

# %%
print('Alex Rodriguez Covariance Homeruns')
ARHRCOV= np.array([ARod.Age,ARod.HR])
covMatrix5 = np.cov(ARHRCOV,bias=True)
covMatrix5
# Out:
# Alex Rodriguez Covariance Homeruns
# array([[ 42.15082645, -14.01239669],
#        [-14.01239669, 262.14049587]])

# %%
#Creates Covariance Matrix for age and hits#
print('Barry Bonds Covariance Hits')
BBHCOV= np.array([BarryBonds.Age,BarryBonds.H])
covMatrixH = np.cov(BBHCOV,bias=True)
covMatrixH
# Out:
# Barry Bonds Covariance Hits
# array([[  36.66666667,  -71.71428571],
#        [ -71.71428571, 1263.53741497]])

# %%
print('Babe Ruth Covariance Hits')
BRHCOV= np.array([BabeRuth.Age,BabeRuth.H])
covMatrixH2 = np.cov(BRHCOV,bias=True)
covMatrixH2
# Out:
# Babe Ruth Covariance Hits
# array([[  40.25      ,  157.84090909],
#        [ 157.84090909, 4381.87809917]])

# %%
print('Hank Aaron Covariance Hits')
HAHCOV= np.array([HankAaron.Age,HankAaron.H])
covMatrixH3 = np.cov(HAHCOV,bias=True)
covMatrixH3
# Out:
# Hank Aaron Covariance Hits
# array([[  44.        , -191.7826087 ],
#        [-191.7826087 , 1576.47637051]])

# %%
print('Willie Mays Covariance Hits')
WMHCOV= np.array([WillieMays.Age.fillna(0),WillieMays.H.fillna(0)])
covMatrixH4 = np.cov(WMHCOV,bias=True)
covMatrixH4
# Out:
# Willie Mays Covariance Hits
# array([[  45.66493056, -195.44444444],
#        [-195.44444444, 3355.97222222]])

# %%
print('Alex Rodriguez Covariance Hits')
ARHCOV= np.array([ARod.Age.fillna(0),ARod.H.fillna(0)])
covMatrixH5 = np.cov(ARHCOV,bias=True)
covMatrixH5
# Out:
# Alex Rodriguez Covariance Hits
# array([[  42.15082645,  -83.03099174],
#        [ -83.03099174, 3501.6053719 ]])

# %%
#Correlation for variable relationships#

print('Barry Bonds Correlation')
print(BarryBonds.corr())
print('')
print('Babe Ruth Correlation')
print(BabeRuth.corr())
print('')
print('Hank Aaron Correlation')
print(HankAaron.corr())
print('')
print('Willie Mays Correlation')
print(WillieMays.corr())
print('')
print('Alex Rodriguez Correlation')
print(ARod.corr())
# Out:
# Barry Bonds Correlation
#           Year       Age         G         R         H        2B        HR  \
# Year  1.000000  1.000000 -0.332099 -0.042961 -0.333178 -0.426389  0.348680
# Age   1.000000  1.000000 -0.332099 -0.042961 -0.333178 -0.426389  0.348680
# G    -0.332099 -0.332099  1.000000  0.870807  0.946503  0.857126  0.512201
# R    -0.042961 -0.042961  0.870807  1.000000  0.902385  0.734696  0.800801
# H    -0.333178 -0.333178  0.946503  0.902385  1.000000  0.862332  0.589397
# 2B   -0.426389 -0.426389  0.857126  0.734696  0.862332  1.000000  0.371877
# HR    0.348680  0.348680  0.512201  0.800801  0.589397  0.371877  1.000000
# RBI   0.120255  0.120255  0.709735  0.836431  0.776591  0.598069  0.803616
# BA    0.640445  0.640445  0.207692  0.495006  0.342334  0.105698  0.676208
# OBP   0.745094  0.745094  0.176398  0.491375  0.235278  0.040717  0.688360
# SLG   0.843678  0.843678 -0.057773  0.338415  0.047584 -0.124925  0.749055
#
# ...

# %%
#Testing Correlation to see about age and performance#
print('Barry Bonds Homeruns')
BBHRP = BarryBonds.Age.values, BarryBonds.HR.values
ht1 = CorrelationPermute(BBHRP)
pvalue1 = ht1.PValue()
print(pvalue1)

print('Barry Bonds Hits')
BBHP = BarryBonds.Age.values, BarryBonds.H.values
ht2 = CorrelationPermute(BBHP)
pvalue2 = ht2.PValue()
print(pvalue2)

print('Barry Bonds Batting Average')
BBBAP = BarryBonds.Age.values, BarryBonds.BA.values
ht3 = CorrelationPermute(BBBAP)
pvalue3 = ht3.PValue()
print(pvalue3)

print('Barry Bonds RBI')
BBRBIP = BarryBonds.Age.values, BarryBonds.RBI.values
ht4 = CorrelationPermute(BBRBIP)
pvalue4 = ht4.PValue()
print(pvalue4)

print('Barry Bonds Doubles')
BBDP = BarryBonds.Age.values, BarryBonds['2B'].values
ht5 = CorrelationPermute(BBDP)
pvalue5 = ht5.PValue()
print(pvalue5)
# Out:
# Barry Bonds Homeruns
# 0.121
# Barry Bonds Hits
# 0.129
# Barry Bonds Batting Average
# 0.0
# Barry Bonds RBI
# 0.604
# Barry Bonds Doubles
# 0.04

# %%
#Testing Correlation to see about age and performance#
print('Babe Ruth Homeruns')
BRHRP = BabeRuth.Age.values, BabeRuth.HR.values
ht1 = CorrelationPermute(BRHRP)
pvalue1 = ht1.PValue()
print(pvalue1)

print('Babe Ruth Hits')
BRHP = BabeRuth.Age.values, BabeRuth.H.values
ht2 = CorrelationPermute(BRHP)
pvalue2 = ht2.PValue()
print(pvalue2)

print('Babe Ruth Batting Average')
BRBAP = BabeRuth.Age.values, BabeRuth.BA.values
ht3 = CorrelationPermute(BRBAP)
pvalue3 = ht3.PValue()
print(pvalue3)

print('Babe Ruth RBI')
BRRBIP = BabeRuth.Age.values, BabeRuth.RBI.values
ht4 = CorrelationPermute(BRRBIP)
pvalue4 = ht4.PValue()
print(pvalue4)

print('Babe Ruth Doubles')
BRDP = BabeRuth.Age.values, BabeRuth['2B'].values
ht5 = CorrelationPermute(BRDP)
pvalue5 = ht5.PValue()
print(pvalue5)
# Out:
# Babe Ruth Homeruns
# 0.054
# Babe Ruth Hits
# 0.086
# Babe Ruth Batting Average
# 0.0
# Babe Ruth RBI
# 0.042
# Babe Ruth Doubles
# 0.801

# %%
#Testing Correlation to see about age and performance#
print('Hank Aaron Homeruns')
HAHRP = HankAaron.Age.values, HankAaron.HR.values
ht1 = CorrelationPermute(HAHRP)
pvalue1 = ht1.PValue()
print(pvalue1)

print('Hank Aaron Hits')
HAHP = HankAaron.Age.values, HankAaron.H.values
ht2 = CorrelationPermute(HAHP)
pvalue2 = ht2.PValue()
print(pvalue2)

print('Hank Aaron Batting Average')
HABAP = HankAaron.Age.values, HankAaron.BA.values
ht3 = CorrelationPermute(HABAP)
pvalue3 = ht3.PValue()
print(pvalue3)

print('Hank Aaron RBI')
HARBIP = HankAaron.Age.values, HankAaron.RBI.values
ht4 = CorrelationPermute(HARBIP)
pvalue4 = ht4.PValue()
print(pvalue4)

print('Hank Aaron Doubles')
HADP = HankAaron.Age.values, HankAaron['2B'].values
ht5 = CorrelationPermute(HADP)
pvalue5 = ht5.PValue()
print(pvalue5)
# Out:
# Hank Aaron Homeruns
# 0.575
# Hank Aaron Hits
# 0.0
# Hank Aaron Batting Average
# 0.001
# Hank Aaron RBI
# 0.033
# Hank Aaron Doubles
# 0.0

# %%
#Testing Correlation to see about age and performance#
print('Willie Mays Homeruns')
WMHRP = WillieMays.Age.fillna(0).values, WillieMays.HR.fillna(0).values
ht1 = CorrelationPermute(WMHRP)
pvalue1 = ht1.PValue()
print(pvalue1)

print('Willie Mays  Hits')
WMHP = WillieMays.Age.fillna(0).values, WillieMays.H.fillna(0).values
ht2 = CorrelationPermute(WMHP)
pvalue2 = ht2.PValue()
print(pvalue2)

print('Willie Mays  Batting Average')
WMBAP = WillieMays.Age.fillna(0).values, WillieMays.BA.fillna(0).values
ht3 = CorrelationPermute(WMBAP)
pvalue3 = ht3.PValue()
print(pvalue3)

print('Willie Mays  RBI')
WMRBIP = WillieMays.Age.fillna(0).values, WillieMays.RBI.fillna(0).values
ht4 = CorrelationPermute(WMRBIP)
pvalue4 = ht4.PValue()
print(pvalue4)

print('Willie Mays  Doubles')
WMDP = WillieMays['Age'].fillna(0).values, WillieMays['2B'].fillna(0).values
ht5 = CorrelationPermute(WMDP)
pvalue5 = ht5.PValue()
print(pvalue5)
# Out:
# Willie Mays Homeruns
# 0.038
# Willie Mays  Hits
# 0.012
# Willie Mays  Batting Average
# 0.01
# Willie Mays  RBI
# 0.025
# Willie Mays  Doubles
# 0.041

# %%
#Testing Correlation to see about age and performance#
print('Alex Rodriguez Homeruns')
ARHRP = ARod.Age.fillna(0).values, ARod.HR.fillna(0).values
ht1 = CorrelationPermute(ARHRP)
pvalue1 = ht1.PValue()
print(pvalue1)

print('Alex Rodriguez Hits')
ARHP = ARod.Age.fillna(0).values, ARod.H.fillna(0).values
ht2 = CorrelationPermute(ARHP)
pvalue2 = ht2.PValue()
print(pvalue2)

print('Alex Rodriguez Batting Average')
ARBAP = ARod.Age.fillna(0).values, ARod.BA.fillna(0).values
ht3 = CorrelationPermute(ARBAP)
pvalue3 = ht3.PValue()
print(pvalue3)

print('Alex Rodriguez RBI')
ARRBIP = ARod.Age.fillna(0).values, ARod.RBI.fillna(0).values
ht4 = CorrelationPermute(ARRBIP)
pvalue4 = ht4.PValue()
print(pvalue4)

print('Alex Rodriguez Doubles')
ARDP = ARod.Age.fillna(0).values, ARod['2B'].fillna(0).values
ht5 = CorrelationPermute(ARDP)
pvalue5 = ht5.PValue()
print(pvalue5)
# Out:
# Alex Rodriguez Homeruns
# 0.542
# Alex Rodriguez Hits
# 0.33
# Alex Rodriguez Batting Average
# 0.186
# Alex Rodriguez RBI
# 0.568
# Alex Rodriguez Doubles
# 0.188

# %%
#Creates Regression Data for Age vs Home Runs#
X2 = BarryBonds.Age
X2 = sm.add_constant(X2)
y2 = BarryBonds.HR
mod = sm.OLS(y2,X2)
res = mod.fit()
print('Barry Bonds')

print(res.summary())
# Out:
# Barry Bonds
#                             OLS Regression Results
# ...
# Dep. Variable:                     HR   R-squared:                       0.122
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     2.630
# Date:                Sun, 21 Feb 2021   Prob (F-statistic):              0.121
# Time:                        14:06:24   Log-Likelihood:                -83.798
# No. Observations:                  21   AIC:                             171.6
# Df Residuals:                      19   BIC:                             173.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.0316     15.658      0.641      0.529     -22.741      42.804
# ...

# %%
plt.title('Barry Bonds Linear Regression  ')
plt.xlabel('Age')
plt.ylabel('Home Runs')
plt.xlim(18,50)

plt.plot(X2,y2, color= 'orange')

# %%
#Creates Regression Data for Age vs Home Runs#
X3 = BabeRuth.Age
X3 = sm.add_constant(X3)

y3 = BabeRuth.HR
mod3 = sm.OLS(y2,X2)
res3 = mod3.fit()
print('Babe Ruth')

print(res3.summary())
# Out:
# Babe Ruth
#                             OLS Regression Results
# ...
# Dep. Variable:                     HR   R-squared:                       0.122
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     2.630
# Date:                Sun, 21 Feb 2021   Prob (F-statistic):              0.121
# Time:                        14:06:27   Log-Likelihood:                -83.798
# No. Observations:                  21   AIC:                             171.6
# Df Residuals:                      19   BIC:                             173.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.0316     15.658      0.641      0.529     -22.741      42.804
# ...

# %%
plt.title('Babe Ruth Linear Regression  ')
plt.xlabel('Age')
plt.ylabel('Home Runs')
plt.xlim(18,50)

plt.plot(X3,y3, color= 'blue')

# %%
#Creates Regression Data for Age vs Home Runs#
X4 = HankAaron.Age
X4 = sm.add_constant(X4)

y4 = HankAaron.HR
mod4 = sm.OLS(y4,X4)
res4 = mod4.fit()
print('Hank Aaron')

print(res4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     HR   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.032
# Method:                 Least Squares   F-statistic:                    0.3092
# Date:                Sun, 21 Feb 2021   Prob (F-statistic):              0.584
# Time:                        14:04:25   Log-Likelihood:                -87.487
# No. Observations:                  23   AIC:                             179.0
# Df Residuals:                      21   BIC:                             181.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         38.9832     11.323      3.443      0.002      15.435      62.532
# ...

# %%
plt.title('Hank Aaron Linear Regression  ')
plt.xlabel('Age')
plt.ylabel('Home Runs')
plt.xlim(18,50)

plt.plot(X4,y4, color= 'red')

# %%
#Creates Regression Data for Age vs Home Runs#
X5 = WillieMays.Age

y5 = WillieMays.HR
mod5 = sm.OLS(y5,X5)
res5 = mod5.fit()
print('Willie Mays')

print(res5.summary())
# Out:
# Willie Mays
#                                  OLS Regression Results
# ...
# Dep. Variable:                     HR   R-squared (uncentered):                   0.663
# Model:                            OLS   Adj. R-squared (uncentered):              0.649
# Method:                 Least Squares   F-statistic:                              45.32
# Date:                Sun, 21 Feb 2021   Prob (F-statistic):                    7.24e-07
# Time:                        14:16:13   Log-Likelihood:                         -104.00
# No. Observations:                  24   AIC:                                      210.0
# Df Residuals:                      23   BIC:                                      211.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
plt.title('Willie Mays Linear Regression  ')
plt.xlabel('Age')
plt.ylabel('Home Runs')
plt.xlim(18,50)

plt.plot(X5,y5, color= 'black')

# %%
X6 = ARod.Age
X6 = sm.add_constant(X6)

y6 = ARod.HR
mod5 = sm.OLS(y6,X6)
res5 = mod5.fit()
print('Alex Rodriguez')
print(res5.summary())
# Out:
# Alex Rodriguez
#                             OLS Regression Results
# ...
# Dep. Variable:                     HR   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.031
# Method:                 Least Squares   F-statistic:                    0.3618
# Date:                Sun, 21 Feb 2021   Prob (F-statistic):              0.554
# Time:                        14:16:19   Log-Likelihood:                -92.277
# No. Observations:                  22   AIC:                             188.6
# Df Residuals:                      20   BIC:                             190.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         41.1410     16.203      2.539      0.020       7.342      74.940
# ...

# %%
plt.title('Alex Rodriguez Linear Regression  ')
plt.xlabel('Age')
plt.ylabel('Home Runs')
plt.xlim(18,50)

plt.plot(X6,y6, color= 'green')

# %%
plt.plot(X2,y2, color= 'orange', label='Bonds')

plt.plot(X3,y3, color= 'blue', label='Ruth')

plt.plot(X4,y4, color= 'red', label='Aaron')
plt.plot(X5,y5, color= 'black', label='Mays')
plt.plot(X6,y6, color= 'green', label='Rodriguez')
plt.xlim(18,50)
plt.legend(loc="lower right")
plt.xlabel('Age')
plt.ylabel('Home Runs')
plt.title('Total Linear Regression  ')
# Out:
# Text(0.5, 1.0, 'Total Linear Regression  ')
